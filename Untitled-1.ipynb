# %%
#Question 1 part A
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread(r'C:\Users\User\Downloads\runway.png',cv.IMREAD_GRAYSCALE)
img1= img/255

gamma=0.5
a=img1**gamma

cv.imshow('Gamma 0.5 image', a)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
#Question 1 part B
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread(r'C:\Users\User\Downloads\runway.png',cv.IMREAD_GRAYSCALE)
img1= img/255

gamma=2
a=img1**gamma

cv.imshow('Gamma 2 image', a)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
#Question 1 part C
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread(r'C:\Users\User\Downloads\runway.png',cv.IMREAD_GRAYSCALE)
img1= img/255

r1, r2 = 0.2, 0.8
output = np.zeros_like(img1)

output[img1 >= r1] = 0
output[(img1 >= r1) & (img1 <= r2)] = \
    (img1[(img1 >= r1) & (img1 <= r2)]-r1)/(r2-r1)
output[img1 > r2] = 1

output1 = np.uint8(output*255)

cv.imshow('Resulting Image',output1)
cv.waitKey(0)
cv.destroyAllWindows()
